# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
us = pd.read_csv("/Users/shanisewalker/DropBox/Data Science Bootcamp/Fall 2023/usp_data.csv")

# %%
us.shape
# Out:
# (3111, 60)

# %%
us.head()
# Out:
#    cnty_fips display_name State  heart_disease  high_cholesterol  \
# 0       1003      Baldwin    AL            8.0              37.9
# 1       1005      Barbour    AL           10.1              38.6
# 2       1011      Bullock    AL            9.7              36.1
# 3       1013       Butler    AL            9.4              39.6
# 4       1023      Choctaw    AL           10.3              40.0
#
#    diagnosed_diabetes  obesity  physical_inactivity  current_smoker  \
# 0                 7.9     27.7                 22.8            16.1
# 1                11.3     24.8                 27.5            24.8
# 2                 9.1     21.2                 20.6            25.1
# 3                12.5     29.1                 29.9            20.9
# 4                10.4     27.9                 27.2            20.2
#
#    broadband_internet  ...  hospital_neurolgical_services  \
# 0                14.9  ...                              1
# ...

# %%
us.tail()
# Out:
#       cnty_fips display_name State  heart_disease  high_cholesterol  \
# 3106      56021      Laramie    WY            5.9              28.1
# 3107      56027     Niobrara    WY            9.7              31.0
# 3108      56031       Platte    WY            8.6              33.5
# 3109      56045       Weston    WY            8.0              32.6
# 3110      56033     Sheridan    WY            6.9              31.3
#
#       diagnosed_diabetes  obesity  physical_inactivity  current_smoker  \
# 3106                 8.7     28.4                 21.9            17.6
# 3107                 7.1     29.7                 26.8            21.0
# 3108                 7.3     25.8                 24.0            17.3
# 3109                 8.1     33.8                 23.6            19.5
# 3110                 7.2     25.2                 19.7            16.5
#
#       broadband_internet  ...  hospital_neurolgical_services  \
# 3106                11.4  ...                              2
# ...

# %%
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3111 entries, 0 to 3110
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   cnty_fips                                                   3111 non-null   int64
#  1   display_name                                                3111 non-null   object
#  2   State                                                       3111 non-null   object
#  3   heart_disease                                               3111 non-null   float64
#  4   high_cholesterol                                            3111 non-null   float64
#  5   diagnosed_diabetes                                          3111 non-null   float64
#  6   obesity                                                     3111 non-null   float64
# ...

# %%
us.describe()
# Out:
#           cnty_fips  heart_disease  high_cholesterol  diagnosed_diabetes  \
# count   3111.000000    3111.000000       3111.000000         3111.000000
# mean   30704.940855       8.207715         34.977371            8.668917
# std    15014.861468       1.598381          4.677034            1.830146
# min     1001.000000      -1.000000         -1.000000           -1.000000
# 25%    19046.000000       7.200000         33.000000            7.500000
# 50%    29215.000000       8.300000         35.500000            8.400000
# 75%    46012.000000       9.300000         37.700000            9.600000
# max    69000.000000      14.100000         45.300000           17.600000
#
#            obesity  physical_inactivity  current_smoker  broadband_internet  \
# count  3111.000000          3111.000000     3111.000000         3111.000000
# mean     28.325747            22.876760       18.890453           21.442269
# std       5.464195             4.451104        3.972802            8.245120
# ...

# %%
us.columns
# Out:
# Index(['cnty_fips', 'display_name', 'State', 'heart_disease',
#        'high_cholesterol', 'diagnosed_diabetes', 'obesity',
#        'physical_inactivity', 'current_smoker', 'broadband_internet',
#        'computer', 'education_lessthan_highschool',
#        'education_lessthan_college', 'foodstamp_snap', 'median_home_value',
#        'median_household_income', 'income_inequality', 'poverty',
#        'severe_housing_cost_burden', 'unemployment_rate', 'air_quality',
#        'park_access', 'urban_rural_value', 'population_all_genders18+',
#        'population_women18+', 'population_men18+', 'population_all_ages',
#        'population_over65_percent',
#        'american_indian_alaska_native_all_ages_nh_percent',
#        'asian_pacific_islander_all_ages_nh_percent',
#        'black_all_ages_nh_percent', 'white_all_ages_nh_percent',
#        'some_other_race_all_ages_nh_percent',
#        'two_ormore_races_all_ages_nh_percent', 'hispanic_all_ages_percent',
# ...

# %%
us.isnull().sum()
# Out:
# cnty_fips                                                     0
# display_name                                                  0
# State                                                         0
# heart_disease                                                 0
# high_cholesterol                                              0
# diagnosed_diabetes                                            0
# obesity                                                       0
# physical_inactivity                                           0
# current_smoker                                                0
# broadband_internet                                            0
# computer                                                      0
# education_lessthan_highschool                                 0
# education_lessthan_college                                    0
# foodstamp_snap                                                0
# median_home_value                                             0
# ...

# %%
us = us.drop(["cnty_fips", "display_name", "State"], axis=1)

# %%
us.head()
# Out:
#    heart_disease  high_cholesterol  diagnosed_diabetes  obesity  \
# 0            8.0              37.9                 7.9     27.7
# 1           10.1              38.6                11.3     24.8
# 2            9.7              36.1                 9.1     21.2
# 3            9.4              39.6                12.5     29.1
# 4           10.3              40.0                10.4     27.9
#
#    physical_inactivity  current_smoker  broadband_internet  computer  \
# 0                 22.8            16.1                14.9       8.2
# 1                 27.5            24.8                35.4      20.2
# 2                 20.6            25.1                39.4      20.3
# 3                 29.9            20.9                26.4      20.7
# 4                 27.2            20.2                37.2      21.8
#
#    education_lessthan_highschool  education_lessthan_college  ...  \
# 0                            9.5                        68.1  ...
# ...

# %%
#Split 
X = us.iloc[:, 1:]
y = us.iloc[:, 1]

# %%
X.head()
# Out:
#    high_cholesterol  diagnosed_diabetes  obesity  physical_inactivity  \
# 0              37.9                 7.9     27.7                 22.8
# 1              38.6                11.3     24.8                 27.5
# 2              36.1                 9.1     21.2                 20.6
# 3              39.6                12.5     29.1                 29.9
# 4              40.0                10.4     27.9                 27.2
#
#    current_smoker  broadband_internet  computer  \
# 0            16.1                14.9       8.2
# 1            24.8                35.4      20.2
# 2            25.1                39.4      20.3
# 3            20.9                26.4      20.7
# 4            20.2                37.2      21.8
#
#    education_lessthan_highschool  education_lessthan_college  foodstamp_snap  \
# 0                            9.5                        68.1             8.9
# 1                           25.3                        88.4            23.7
# ...

# %%
y.head()
# Out:
# 0    37.9
# 1    38.6
# 2    36.1
# 3    39.6
# 4    40.0
# Name: high_cholesterol, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=153)

# %%
from xgboost import XGBRegressor

# %%
xg_reg = XGBRegressor()

# %%
xg_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
y_pred = xg_reg.predict(X_test)

# %%
y_pred
# Out:
# array([29.394732  , 32.020008  , 43.519882  , 37.39282   , 34.80228   ,
#        39.500755  , 38.494354  , 37.38892   , 34.203327  , 30.904554  ,
#        34.498596  , 36.499435  , 35.20079   , 32.5032    , 42.594208  ,
#        39.33327   , 37.88949   , 34.0028    , 31.106997  , 41.45851   ,
#        35.89976   , 33.80149   , 30.976915  , 31.803225  , 38.408634  ,
#        32.59635   , 39.81924   , 33.199528  , 33.504604  , 35.203453  ,
#        37.195877  , 35.402916  , 37.09119   , 33.299713  , 32.27325   ,
#        35.40142   , 35.20224   , 35.596058  , 39.816727  , 35.301464  ,
#        38.909042  , 35.49773   , 40.40343   , 30.48076   , 37.013847  ,
#        40.41623   , 39.12159   , 38.983578  , 36.602013  , 34.800545  ,
#        42.1221    , 42.127876  , 35.202877  , 32.214424  , 36.79744   ,
#        33.700542  , 33.897175  , 38.70519   , 38.908867  , 34.296677  ,
#        31.302279  , 36.70076   , 32.70239   , 32.70094   , 29.782507  ,
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print("MSE: %0.3f" % (mse))
# Out:
# MSE: 0.001

# %%
rmse = np.sqrt(mse)

# %%
print("RMSE: %0.3f" % (rmse))
# Out:
# RMSE: 0.036

# %%
from sklearn.model_selection import cross_val_score

# %%
model = XGBRegressor(objective = "reg:squarederror")

# %%
scores = cross_val_score(model, X_train, y_train, 
                        scoring= "neg_mean_squared_error", 
                       cv= 10)

# %%
scores
# Out:
# array([-2.86815665e-03, -2.03686064e-03, -8.33165768e-04, -2.48482911e-03,
#        -1.90512617e-03, -3.84989553e-03, -6.48145534e-04, -9.27631270e-04,
#        -1.88182536e+00, -1.77794154e-03])

# %%
rmse = np.sqrt(-scores)

# %%
print(rmse)
# Out:
# [0.05355517 0.04513159 0.02886461 0.04984806 0.04364775 0.06204753
#  0.0254587  0.03045704 1.3717964  0.04216564]

# %%
from xgboost import plot_importance

plt.rcParams["figure.figsize"] = (14, 14)
plot_importance(xg_reg)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>
